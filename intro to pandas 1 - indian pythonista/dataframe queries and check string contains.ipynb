# %%
import pandas as pd

# %%
df = pd.read_csv("data/imdb_1000.csv")

# %%
df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df[df['genre'] == 'Crime']
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating  genre  duration  \
# 0                R  Crime       142
# 1                R  Crime       175
# 2                R  Crime       200
# ...

# %%
df.query('genre == "Crime"')
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating  genre  duration  \
# 0                R  Crime       142
# 1                R  Crime       175
# 2                R  Crime       200
# ...

# %%
df.query("genre == 'Crime' & star_rating > 9")
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
# 2          9.1    The Godfather: Part II              R  Crime       200
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...

# %%
df.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
df.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
df.query("genre == 'Crime' & star_rating > 9").sort_index(ascending=False)
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 2          9.1    The Godfather: Part II              R  Crime       200
# 1          9.2             The Godfather              R  Crime       175
# 0          9.3  The Shawshank Redemption              R  Crime       142
#
#                                          actors_list
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...

# %%
df.query("genre == 'Crime' & star_rating > 9").sort_index(axis=1)
# Out:
#                                          actors_list content_rating  duration  \
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...              R       142
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']              R       175
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...              R       200
#
#    genre  star_rating                     title
# 0  Crime          9.3  The Shawshank Redemption
# 1  Crime          9.2             The Godfather
# 2  Crime          9.1    The Godfather: Part II

# %%
# filter by multiple columns

# %%
df.query("genre == 'Crime' & star_rating > 8")
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 3            9.0           The Dark Knight          PG-13  Crime       152
# 4            8.9              Pulp Fiction              R  Crime       154
# ..           ...                       ...            ...    ...       ...
# 292          8.1  The Manchurian Candidate       APPROVED  Crime       126
# 293          8.1                 Duck Soup         PASSED  Crime        68
# 294          8.1      Beauty and the Beast              G  Crime        84
# 295          8.1           The Truman Show             PG  Crime       103
# 296          8.1            The Wild Bunch              R  Crime       145
#
#                                            actors_list
# ...

# %%
# Sort values by mutliple columns

# %%
df.query("genre == 'Crime'").sort_values(['star_rating', 'duration'])
# Out:
#      star_rating                                          title  \
# 938          7.4                            Alice in Wonderland
# 948          7.4                                     Frances Ha
# 966          7.4                             The Simpsons Movie
# 947          7.4                                     Eraserhead
# 971          7.4                             Death at a Funeral
# ..           ...                                            ...
# 7            8.9  The Lord of the Rings: The Return of the King
# 3            9.0                                The Dark Knight
# 2            9.1                         The Godfather: Part II
# 1            9.2                                  The Godfather
# 0            9.3                       The Shawshank Redemption
#
#     content_rating  genre  duration  \
# 938              G  Crime        75
# 948              R  Crime        86
# 966          PG-13  Crime        87
# 947        UNRATED  Crime        89
# ...

# %%
# filter by contains string

# %%
df.query("genre == 'Crime' & content_rating.str.contains('PG')")
# Out:
#      star_rating                                              title  \
# 3            9.0                                    The Dark Knight
# 7            8.9      The Lord of the Rings: The Return of the King
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ..           ...                                                ...
# 973          7.4                              The Cider House Rules
# 974          7.4                                            Tootsie
# 975          7.4                        Back to the Future Part III
# 976          7.4    Master and Commander: The Far Side of the World
# 977          7.4                                        Poltergeist
#
#     content_rating  genre  duration  \
# 3            PG-13  Crime       152
# 7            PG-13  Crime       201
# 10           PG-13  Crime       178
# ...

# %%
df.query("genre.str.contains('Crime')")
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating  genre  duration  \
# 0                R  Crime       142
# 1                R  Crime       175
# 2                R  Crime       200
# ...

# %%
df.query("star_rating > 8 & genre.str.contains('Crime|Action')")
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 3            9.0           The Dark Knight          PG-13  Crime       152
# 4            8.9              Pulp Fiction              R  Crime       154
# ..           ...                       ...            ...    ...       ...
# 292          8.1  The Manchurian Candidate       APPROVED  Crime       126
# 293          8.1                 Duck Soup         PASSED  Crime        68
# 294          8.1      Beauty and the Beast              G  Crime        84
# 295          8.1           The Truman Show             PG  Crime       103
# 296          8.1            The Wild Bunch              R  Crime       145
#
#                                            actors_list
# ...

# %%
teams = pd.DataFrame({'team': ['Cavs', 'Heat', 'Mavs', 'Mavs', 'Nets',
                            'Heat', 'Cavs', 'Jazz', 'Jazz', 'Hawks'],
                   'points': [3, 3, 4, 5, 4, 7, 8, 7, 12, 14],
                   'rebounds': [15, 14, 14, 10, 8, 14, 13, 9, 5, 4]})

# %%
teams
# Out:
#     team  points  rebounds
# 0   Cavs       3        15
# 1   Heat       3        14
# 2   Mavs       4        14
# 3   Mavs       5        10
# 4   Nets       4         8
# 5   Heat       7        14
# 6   Cavs       8        13
# 7   Jazz       7         9
# 8   Jazz      12         5
# 9  Hawks      14         4

# %%
teams.query("team == 'Cavs'")
# Out:
#    team  points  rebounds
# 0  Cavs       3        15
# 6  Cavs       8        13

# %%
teams.query("team.str.contains('Cavs|eat')")
# Out:
#    team  points  rebounds
# 0  Cavs       3        15
# 1  Heat       3        14
# 5  Heat       7        14
# 6  Cavs       8        13
