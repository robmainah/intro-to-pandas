# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
schema_df
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
schema_df.set_index("Column", inplace=True)

# %%
schema_df.reset_index(inplace=True)

# %%
schema_df
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
schema_df.columns = [x.title() for x in schema_df.columns]
schema_df
# Out:
#                                                    Questiontext
# Column
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %%
schema_df.columns
# Out:
# pandas.core.indexes.base.Index

# %%
schema_df.rename(columns={'Question_text': 'Questiontext'}, inplace=True)
schema_df
# Out:
#                                                    Questiontext
# Column
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %%
schema_df.loc[0, 'Column'] = 'Respondent'

# %%
schema_df
# Out:
#           Column                                       Questiontext
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
schema_df.at[0, 'Column'] = 'Respondent new'

# %%
schema_df
# Out:
#             Column                                       Questiontext
# 0   Respondent new  Randomized respondent ID number (not in order ...
# 1       MainBranch  Which of the following options best describes ...
# 2         Hobbyist                            Do you code as a hobby?
# 3      OpenSourcer        How often do you contribute to open source?
# 4       OpenSource  How do you feel about the quality of open sour...
# ..             ...                                                ...
# 80       Sexuality  Which of the following do you currently identi...
# 81       Ethnicity  Which of the following do you identify as? Ple...
# 82      Dependents  Do you have any dependents (e.g., children, el...
# 83    SurveyLength  How do you feel about the length of the survey...
# 84      SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
filt = schema_df['Column'] == 'Respondent new'
schema_df.loc[filt, 'Column'] = 'Respondent'

# %%
schema_df
# Out:
#           Column                                       Questiontext
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
schema_df['Column'].apply(len)
# Out:
# 0     10
# 1     10
# 2      8
# 3     11
# 4     10
#       ..
# 80     9
# 81     9
# 82    10
# 83    12
# 84    10
# Name: Column, Length: 85, dtype: int64

# %%
def capitalize(value):
    return value.upper()

# %%
schema_df['Column'].apply(capitalize)
# Out:
# 0       RESPONDENT
# 1       MAINBRANCH
# 2         HOBBYIST
# 3      OPENSOURCER
# 4       OPENSOURCE
#           ...
# 80       SEXUALITY
# 81       ETHNICITY
# 82      DEPENDENTS
# 83    SURVEYLENGTH
# 84      SURVEYEASE
# Name: Column, Length: 85, dtype: object

# %%
schema_df['Column'].apply(lambda x: x.upper())
# Out:
# 0       RESPONDENT
# 1       MAINBRANCH
# 2         HOBBYIST
# 3      OPENSOURCER
# 4       OPENSOURCE
#           ...
# 80       SEXUALITY
# 81       ETHNICITY
# 82      DEPENDENTS
# 83    SURVEYLENGTH
# 84      SURVEYEASE
# Name: Column, Length: 85, dtype: object

# %%
schema_df['Column'].apply(len)
# Out:
# 0     10
# 1     10
# 2      8
# 3     11
# 4     10
#       ..
# 80     9
# 81     9
# 82    10
# 83    12
# 84    10
# Name: Column, Length: 85, dtype: int64

# %%
schema_df.apply(len)
# Out:
# Column          85
# Questiontext    85
# dtype: int64

# %%
 schema_df.apply(lambda x: x.min())
# Out:
# Column                                                        Age
# Questiontext    About how much time did you save? If you're no...
# dtype: object

# %%
schema_df.applymap(str.lower)
# Out:
#           Column                                       Questiontext
# 0     respondent  randomized respondent id number (not in order ...
# 1     mainbranch  which of the following options best describes ...
# 2       hobbyist                            do you code as a hobby?
# 3    opensourcer        how often do you contribute to open source?
# 4     opensource  how do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     sexuality  which of the following do you currently identi...
# 81     ethnicity  which of the following do you identify as? ple...
# 82    dependents  do you have any dependents (e.g., children, el...
# 83  surveylength  how do you feel about the length of the survey...
# 84    surveyease  how easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
schema_df
# Out:
#           Column                                       Questiontext
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
schema_df['Column'].map({'Respondent': 'Respondent 1'})
# Out:
# 0     Respondent 1
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#           ...
# 80             NaN
# 81             NaN
# 82             NaN
# 83             NaN
# 84             NaN
# Name: Column, Length: 85, dtype: object

# %%
schema_df['Column'] = schema_df['Column'].replace({'Respondent': 'Respondent 1'})
schema_df
# Out:
#           Column                                       Questiontext
# 0   Respondent 1  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
schema_df['Column'] = schema_df['Column'].replace({'Respondent 1': 'Respondent'})
schema_df
# Out:
#           Column                                       Questiontext
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)
df.head(2)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %%
df.rename(columns={'ConvertedComp': 'SalaryUsd'}, inplace=True)
df.head(2)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes': True, 'No': False})

# %%
df.head(2)
# Out:
#                                         MainBranch  Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      True
# 2           I am a student who is learning to code     False
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %%
df['Hobbyist'].unique()
# Out:
# array([ True, False])

# %%
df['Hobbyist'].value_counts()
# Out:
# True     71257
# False    17626
# Name: Hobbyist, dtype: int64
