# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')
schema = pd.read_csv('data/survey_results_schema.csv')

# %%
schema_df
# Out:
#                                                    QuestionText
# Column
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %%
filt = (schema['Column'] == 'Hobbyist')

# %%
schema.loc[filt, ['Column', 'QuestionText']]
# Out:
#      Column             QuestionText
# 2  Hobbyist  Do you code as a hobby?

# %%
schema_df.columns
# Out:
# Index(['QuestionText'], dtype='object')

# %%
schema_df.loc['Hobbyist']
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
filt1 = (schema['Column'] == 'Hobbyist') | (schema['QuestionText'].str.contains('code'))

# %%
schema.loc[filt1]
# Out:
#           Column                                       QuestionText
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 14    Age1stCode  At what age did you write your first line of c...
# 15  YearsCodePro  How many years have you coded professionally (...
# 38       CodeRev           Do you review code as part of your work?
# 39    CodeRevHrs  On average, how many hours per week do you spe...

# %%
schema.loc[~filt1] # opposite/negate of filter
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# 5     Employment  Which of the following best describes your cur...
# 6        Country          In which country do you currently reside?
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [79 rows x 2 columns]

# %%
salary_col = schema['QuestionText'].str.contains('salary')

# %%
# schema.loc[salary_col]
# schema.iloc[29, 1] # loc uses only integers
schema.loc[29, 'QuestionText'] # loc uses strings
# schema_df.loc['CompTotal', 'QuestionText']
# Out:
# 'What is your current total compensation (salary, bonuses, and perks, before taxes and deductions), in `CurrencySymbol`? Please enter a whole number in the box below, without any punctuation. If you are paid hourly, please estimate an equivalent weekly, monthly, or yearly salary. If you prefer not to answer, please leave the box empty.'

# %%
schema
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head(4)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
# 3                             Never
# 4                             Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
#
# ...

# %%
high_salary = (df['ConvertedComp'] > 70000) & (df['CompFreq'] == 'Monthly')

# %%
df.loc[high_salary, ['Country', 'LanguageWorkedWith', 'ConvertedComp', 'CompFreq']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 44                 Germany  Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...
# 83                   India                                HTML/CSS;JavaScript
# 128         United Kingdom                      Bash/Shell/PowerShell;Go;Ruby
# ...                    ...                                                ...
# 88799               Sweden                                            C#;Rust
# 88867             Portugal            Bash/Shell/PowerShell;JavaScript;Python
# 88868              Germany                 HTML/CSS;JavaScript;PHP;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
# ...

# %%
countries = ['United States', 'India', 'United Kingdom', 'Germany', 'Canada']
filt = df['Country'].isin(countries)

# %%
selected_columns = ['Country', 'LanguageWorkedWith', 'ConvertedComp']

# %%
df.loc[filt, selected_columns]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 1           United Kingdom                    HTML/CSS;Java;JavaScript;Python
# 4            United States                                C;C++;C#;Python;SQL
# 6                   Canada                                         Java;R;SQL
# 8                    India  Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 10                   India                      C#;Go;JavaScript;Python;R;SQL
# ...                    ...                                                ...
# 85642        United States                                        Go;HTML/CSS
# 85961       United Kingdom                                    C;C++;Other(s):
# 86012                India      Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript
# 88282        United States  Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;W...
# 88377               Canada                      HTML/CSS;JavaScript;Other(s):
#
# ...

# %%
df.loc[filt, 'Country'].value_counts()
# Out:
# United States     20949
# India              9061
# Germany            5866
# United Kingdom     5737
# Canada             3395
# Name: Country, dtype: int64

# %%
df['LanguageWorkedWith'][1].split(';')
# Out:
# ['HTML/CSS', 'Java', 'JavaScript', 'Python']

# %%
has_python = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[has_python, 'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
mul = filt & has_python & high_salary

# %%
df.loc[mul, selected_columns]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 262          United States  C++;C#;HTML/CSS;Java;JavaScript;PHP;Python;SQL...
# 788         United Kingdom  C++;HTML/CSS;JavaScript;Python;TypeScript;WebA...
# 789          United States                                       C#;F#;Python
# 799          United States                                       C;C++;Python
# 872          United States  Bash/Shell/PowerShell;C;HTML/CSS;JavaScript;Py...
# ...                    ...                                                ...
# 88278        United States          HTML/CSS;JavaScript;Python;SQL;TypeScript
# 88421       United Kingdom  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 88615                India      Bash/Shell/PowerShell;Java;Python;R;Scala;SQL
# 88696        United States                         HTML/CSS;JavaScript;Python
# 88714               Canada  Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#
# ...
