# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
schema_df.sort_values('Column', ascending=False)
# Out:
#            Column                                       QuestionText
# 15   YearsCodePro  How many years have you coded professionally (...
# 13      YearsCode  Including any education, how many years have y...
# 32    WorkWeekHrs   On average, how many hours per week do you work?
# 35     WorkRemote                    How often do you work remotely?
# 33       WorkPlan            How structured or planned is your work?
# ..            ...                                                ...
# 56  BlockchainOrg  How is your organization thinking about or imp...
# 57   BlockchainIs  Blockchain / cryptocurrency technology is prim...
# 58     BetterLife  Do you think people born today will have a bet...
# 14     Age1stCode  At what age did you write your first line of c...
# 77            Age  What is your age (in years)? If you prefer not...
#
# [85 rows x 2 columns]

# %%
df.head(4).sort_values(['Hobbyist', 'Employment'])
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 4                              I am a developer by profession       No
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 1                      I am a student who is learning to code      Yes
#
#                         OpenSourcer  \
# Respondent
# 4                             Never
# 2           Less than once per year
# 3                             Never
# 1                             Never
#
#                                                    OpenSource  \
# Respondent
# 4           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 1           The quality of OSS and closed source software ...
#
# ...

# %%
df.head(4).sort_values(by=['Hobbyist', 'Employment'])
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 4                              I am a developer by profession       No
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 1                      I am a student who is learning to code      Yes
#
#                         OpenSourcer  \
# Respondent
# 4                             Never
# 2           Less than once per year
# 3                             Never
# 1                             Never
#
#                                                    OpenSource  \
# Respondent
# 4           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 1           The quality of OSS and closed source software ...
#
# ...

# %%
df.sort_values(by=['Hobbyist', 'Employment'], ascending=[True, True], inplace=True)

# %%
df.head(4)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 4                              I am a developer by profession       No
# 20          I am not primarily a developer, but I write co...       No
# 25                             I am a developer by profession       No
# 30                             I am a developer by profession       No
#
#                                                   OpenSourcer  \
# Respondent
# 4                                                       Never
# 20                                                      Never
# 25                                                      Never
# 30          Less than once a month but more than once per ...
#
#                                                    OpenSource  \
# Respondent
# 4           The quality of OSS and closed source software ...
# 20          OSS is, on average, of HIGHER quality than pro...
# 25          OSS is, on average, of HIGHER quality than pro...
# ...

# %%
df.sort_index() # reset sorting to default
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88879                          I am a developer by profession      Yes
# 88880       I am not primarily a developer, but I write co...      Yes
# 88881                          I am a developer by profession      Yes
# 88882                          I am a developer by profession      Yes
# 88883                          I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# ...

# %%
df.sort_values(['Country'], inplace=True)
df.head(4)
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 8149        I am a developer by profession      Yes
# 62168          I code primarily as a hobby      Yes
# 86362       I am a developer by profession      Yes
# 85715       I am a developer by profession       No
#
#                            OpenSourcer  \
# Respondent
# 8149        Once a month or more often
# 62168       Once a month or more often
# 86362          Less than once per year
# 85715          Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 8149        OSS is, on average, of LOWER quality than prop...
# 62168       OSS is, on average, of HIGHER quality than pro...
# 86362       The quality of OSS and closed source software ...
# 85715       The quality of OSS and closed source software ...
#
#                                                    Employment      Country  \
# Respondent
# ...

# %%
df[['Country', 'ConvertedComp']]
# Out:
#                 Country  ConvertedComp
# Respondent
# 8149        Afghanistan         1596.0
# 62168       Afghanistan            NaN
# 86362       Afghanistan            NaN
# 85715       Afghanistan            NaN
# 58450       Afghanistan        17556.0
# ...                 ...            ...
# 73670               NaN            NaN
# 83648               NaN            NaN
# 85744               NaN            NaN
# 88062               NaN            NaN
# 88601               NaN            NaN
#
# [88883 rows x 2 columns]

# %%
df.sort_values(['Country', 'ConvertedComp'], ascending=[True, False], inplace=True)
df[['Country', 'ConvertedComp']].head(4)
# Out:
#                 Country  ConvertedComp
# Respondent
# 63129       Afghanistan      1000000.0
# 50499       Afghanistan       153216.0
# 39258       Afghanistan        19152.0
# 58450       Afghanistan        17556.0

# %%
df['ConvertedComp'].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 22013    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df.nlargest(5, 'ConvertedComp')
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 25983                          I am a developer by profession      Yes
# 87896                          I am a developer by profession      Yes
# 28243                          I am a developer by profession      Yes
# 72732       I am not primarily a developer, but I write co...       No
# 22013                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 25983                                 Less than once per year
# 87896                                 Less than once per year
# 28243                              Once a month or more often
# 72732       Less than once a month but more than once per ...
# 22013                                                   Never
#
#                                                    OpenSource  \
# Respondent
# ...
